# %%
from app.data.Document import RAW_DOCUMENT
from app.models.Chunks import ParentChunk
from app.retriever.parent_child_retriever import ParentChildRetriever
from app.utils.Parser import parse_document


def print_structure(parents: list[ParentChunk]) -> None:
    """ساختار parent-child را به‌صورت درخت نمایش می‌دهد."""
    print("=" * 60)
    print("ساختار Parent-Child سند RAG فارسی")
    print("=" * 60)

    for parent in parents:
        preview = parent.content[:80].replace("\n", " ") + "..."
        print(f"\n📁 Parent [{parent.id}]: {parent.title}")
        print(f"   محتوا (پیش‌نمایش): {preview}")

        if parent.children:
            for child in parent.children:
                child_preview = child.content[:60].replace("\n", " ") + "..."
                print(f"   └─ Child [{child.id}]: {child.title}")
                print(f"             محتوا: {child_preview}")
        else:
            print("   └─ (بدون زیرعنوان)")

    total_children = sum(len(p.children) for p in parents)
    print("\n" + "=" * 60)
    print(f"✅ تعداد کل Parents  : {len(parents)}")
    print(f"✅ تعداد کل Children : {total_children}")
    print("=" * 60)


def demo_retrieval(retriever: ParentChildRetriever) -> None:
    """چند نمونه پرسش را اجرا و نتیجه را نمایش می‌دهد."""
    print("\n--- نمونه Retrieval ---")
    test_queries = ["Embedding", "فارسی", "ارزیابی"]

    for query in test_queries:
        print(f"\n🔍 پرسش: '{query}'")
        results = retriever.retrieve(query, top_k=2)

        if not results:
            print("  نتیجه‌ای یافت نشد.")
            continue

        for r in results:
            child = r["matched_child"]
            parent = r["parent"]
            print(f"  ↳ Child یافت‌شده : [{child.id}] {child.title}")
            if parent:
                print(f"     Parent برگشتی : [{parent.id}] {parent.title}")


def main() -> None:
    # ۱. پارس سند
    parents = parse_document(RAW_DOCUMENT)
    # print(parents)
    # ۲. نمایش ساختار
    print_structure(parents)

    # ۳. ساخت retriever
    # retriever = ParentChildRetriever(parents)

    # # ۴. نمونه retrieval
    # demo_retrieval(retriever)

    # print("\n✅ ساختار parent-child آماده است.")
    # print("📌 مرحله بعدی: اضافه کردن embedding و vectorstore.")


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# ساختار Parent-Child سند RAG فارسی
# ============================================================
#
# 📁 Parent [1]: مقدمه و پیشینه
#    محتوا (پیش‌نمایش): در دنیای امروز، مدل‌های زبانی بزرگ (LLM) به یکی از پایه‌های اصلی نرم‌افزارهای هو...
#    └─ (بدون زیرعنوان)
#
# 📁 Parent [2]: اجزای اصلی یک سیستم RAG
#    محتوا (پیش‌نمایش): یک سیستم RAG از چندین مؤلفه کلیدی تشکیل شده است که هر یک نقش مهمی در کیفیت نهایی...
#    └─ Child [2.1]: پردازش و بارگذاری اسناد (Document Ingestion)
#              محتوا: اولین گام در ساخت یک سیستم RAG، آماده‌سازی و بارگذاری اسناد ...
#    └─ Child [2.2]: تقسیم‌بندی متن (Chunking)
#              محتوا: پس از بارگذاری اسناد، متن‌ها به قطعات کوچک‌تری به نام Chunk ...
#    └─ Child [2.3]: تبدیل به بردار (Embedding)
#              محتوا: مرحله بعدی، تبدیل هر قطعه متن به یک بردار عددی چندبعدی است. ...
#    └─ Child [2.4]: پایگاه داده برداری (Vector Store)
#              محتوا: الگوریتم‌های جستجو بر اساس شباهت کسینوسی یا فاصله اقلیدسی عم...
#    └─ Child [2.5]: بازیابی و رتبه‌بندی (Retrieval & Reranking)
#              محتوا: هنگامی که کاربر سؤالی مطرح می‌کند، ابتدا سؤال به بردار تبدیل...
#    └─ Child [2.6]: تولید پاسخ (Generation)
#              محتوا: سؤال کاربر به همراه قطعات بازیابی‌شده به‌عنوان Prompt به مدل...
#
# 📁 Parent [3]: چالش‌های RAG برای زبان فارسی
#    محتوا (پیش‌نمایش): پیاده‌سازی RAG برای زبان فارسی با چالش‌های خاصی همراه است.  [3.1] چندریختی متن ف...
#    └─ Child [3.1]: چندریختی متن فارسی
#              محتوا: زبان فارسی دارای اشکال مختلف نوشتاری برای برخی کاراکترها است...
#    └─ Child [3.2]: اتصال کلمات و توکن‌بندی
#              محتوا: فارسی یک زبان پیوندی (Agglutinative) است؛ پیشوندها و پسوندها...
#    └─ Child [3.3]: کمبود داده‌های آموزشی
#              محتوا: در مقایسه با انگلیسی، حجم داده‌های آموزشی فارسی بسیار کمتر ا...
#    └─ Child [3.4]: راست‌به‌چپ بودن متن
#              محتوا: متن فارسی نیازمند پشتیبانی از نمایش RTL (Right-to-Left) است....
#
# 📁 Parent [4]: معیارهای ارزیابی RAG
#    محتوا (پیش‌نمایش): ارزیابی کیفیت یک سیستم RAG از چندین جنبه انجام می‌شود.  [4.1] دقت بازیابی (Retri...
#    └─ Child [4.1]: دقت بازیابی (Retrieval Accuracy)
#              محتوا: شاخص‌های متداول: Precision@K، Recall@K، MRR (Mean Reciprocal...
#    └─ Child [4.2]: کیفیت تولید (Generation Quality)
#              محتوا: شاخص‌های رایج: BLEU، ROUGE، BERTScore. چارچوب RAGAS معیارهای...
#    └─ Child [4.3]: صحت استناد (Faithfulness)
#              محتوا: مدل نباید دچار توهم‌زایی (Hallucination) شود؛ یعنی اطلاعاتی ...
#
# 📁 Parent [5]: معماری‌های پیشرفته RAG
#    محتوا (پیش‌نمایش): [5.1] HyDE و روش‌های پیشرفته RAG در HyDE (Hypothetical Document Embeddings)، ابت...
#    └─ Child [5.1]: HyDE و روش‌های پیشرفته RAG
#              محتوا: در HyDE (Hypothetical Document Embeddings)، ابتدا یک سند فرض...
#    └─ Child [5.2]: Agentic RAG
#              محتوا: یک Agent تصمیم می‌گیرد آیا بازیابی لازم است، از کدام منابع ا...
#    └─ Child [5.3]: GraphRAG
#              محتوا: به جای قطعات متن، یک Knowledge Graph از اسناد ساخته می‌شود. ...
#
# 📁 Parent [6]: پیاده‌سازی عملی با LangChain
#    محتوا (پیش‌نمایش): LangChain یکی از پرکاربردترین چارچوب‌ها برای ساخت سیستم‌های RAG است. مرحله ۱: با...
#    └─ (بدون زیرعنوان)
#
# 📁 Parent [7]: کاربرد RAG در هوش تجاری (BI)
#    محتوا (پیش‌نمایش): RAG در حوزه هوش تجاری کاربردهای مهمی دارد: - تحلیل خودکار گزارش‌های سازمانی - پا...
#    └─ (بدون زیرعنوان)
#
# 📁 Parent [8]: بهترین رویکردها و توصیه‌ها
#    محتوا (پیش‌نمایش): - تمرکز جدی بر نرمال‌سازی متن فارسی با Hazm - آزمایش مدل‌های مختلف Embedding (25...
#    └─ (بدون زیرعنوان)
#
# 📁 Parent [9]: آینده RAG
#    محتوا (پیش‌نمایش): - Streaming RAG: تولید پاسخ به‌صورت تدریجی - Multimodal RAG: پردازش همزمان متن، ...
#    └─ (بدون زیرعنوان)
#
# 📁 Parent [10]: نتیجه‌گیری
#    محتوا (پیش‌نمایش): RAG یک معماری قدرتمند است که شکاف بین توانایی‌های LLM و نیازهای واقعی سازمان‌ها ...
#    └─ (بدون زیرعنوان)
#
# ============================================================
# ✅ تعداد کل Parents  : 10
# ✅ تعداد کل Children : 16
# ============================================================
